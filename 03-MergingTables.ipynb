# %%
import pandas as pd
import datetime 
import time

# %%
weather2_df = pd.read_csv('Illinois_Daily_Weather_Half.csv')

# %%
weather_df = pd.read_csv('IIllinois_Daily_Weather.csv')

# %%
weather_df.DATE.nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0         2016-03-01
# 1         2016-03-02
# 2         2016-03-03
# 3         2016-03-15
# 4         2016-03-16
# 5         2016-03-17
# 6         2016-03-18
# 7         2016-03-19
# 8         2016-03-20
# 9         2016-03-21
# 10        2016-03-22
# 11        2016-03-23
# 12        2016-03-26
# 13        2016-03-27
# 14        2016-03-28
# 15        2016-03-29
# 16        2016-03-30
# 17        2016-03-31
# 18        2016-04-01
# 19        2016-04-02
# 20        2016-04-03
# 21        2016-04-04
# 22        2016-04-05
# 23        2016-04-06
# 24        2016-04-07
# 25        2016-04-10
# 26        2016-04-11
# 27        2016-04-12
# 28        2016-04-13
# 29        2016-04-14
#              ...
# 100494    2018-08-03
# 100495    2018-08-04
# 100496    2018-08-05
# 100497    2018-08-06
# 100498    2018-08-07
# 100499    2018-08-08
# 100500    2018-08-09
# 100501    2018-08-10
# 100502    2018-08-11
# 100503    2018-08-12
# ...

# %%
weather_df
# Out:
#             STATION                                        NAME        DATE  \
# 0       US1ILDP0098                  DOWNERS GROVE 0.9 S, IL US  2016-03-01
# 1       US1ILDP0098                  DOWNERS GROVE 0.9 S, IL US  2016-03-02
# 2       US1ILDP0098                  DOWNERS GROVE 0.9 S, IL US  2016-03-03
# 3       US1ILDP0098                  DOWNERS GROVE 0.9 S, IL US  2016-03-15
# 4       US1ILDP0098                  DOWNERS GROVE 0.9 S, IL US  2016-03-16
# 5       US1ILDP0098                  DOWNERS GROVE 0.9 S, IL US  2016-03-17
# 6       US1ILDP0098                  DOWNERS GROVE 0.9 S, IL US  2016-03-18
# 7       US1ILDP0098                  DOWNERS GROVE 0.9 S, IL US  2016-03-19
# 8       US1ILDP0098                  DOWNERS GROVE 0.9 S, IL US  2016-03-20
# 9       US1ILDP0098                  DOWNERS GROVE 0.9 S, IL US  2016-03-21
# 10      US1ILDP0098                  DOWNERS GROVE 0.9 S, IL US  2016-03-22
# ...

# %%
weather_df=weather_df[weather_df.NAME == "CHICAGO OHARE INTERNATIONAL AIRPORT, IL US"]

# %%
weather_df
# Out:
#             STATION                                        NAME        DATE  \
# 99549   USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  2016-01-01
# 99550   USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  2016-01-02
# 99551   USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  2016-01-03
# 99552   USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  2016-01-04
# 99553   USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  2016-01-05
# 99554   USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  2016-01-06
# 99555   USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  2016-01-07
# 99556   USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  2016-01-08
# 99557   USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  2016-01-09
# 99558   USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  2016-01-10
# 99559   USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  2016-01-11
# ...

# %%
weather2_df =weather2_df[weather2_df.NAME == "CHICAGO OHARE INTERNATIONAL AIRPORT, IL US"]

# %%
weather2_df=weather2_df[:-1]

# %%
weatherfinal_df = weather2_df.append(weather_df)

# %%
weatherfinal_df
# Out:
#             STATION                                        NAME        DATE  \
# 0       USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  2014-01-21
# 1       USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  2014-01-22
# 2       USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  2014-01-23
# 3       USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  2014-01-24
# 4       USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  2014-01-25
# 5       USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  2014-01-26
# 6       USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  2014-01-27
# 7       USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  2014-01-28
# 8       USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  2014-01-29
# 9       USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  2014-01-30
# 10      USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  2014-01-31
# ...

# %%
traffic_df = pd.read_csv('Traffic_Crashes_-_Crashes.csv')

# %%
traffic_df
# Out:
#                  CRASH_DATE  POSTED_SPEED_LIMIT WEATHER_CONDITION  \
# 0       2018-09-08 02:44:00                  30             CLEAR
# 1       2018-09-08 02:16:00                  30             CLEAR
# 2       2018-09-08 01:53:00                  30             CLEAR
# 3       2018-09-08 01:25:00                  30             CLEAR
# 4       2018-09-08 00:53:00                  35             CLEAR
# 5       2018-09-08 00:38:00                  30             CLEAR
# 6       2018-09-07 23:45:00                  10             CLEAR
# 7       2018-09-07 23:30:00                  30             CLEAR
# 8       2018-09-07 23:00:00                  35             CLEAR
# 9       2018-09-07 22:45:00                  35             CLEAR
# 10      2018-09-07 22:30:00                  30             CLEAR
# 11      2018-09-07 22:29:00                  30             CLEAR
# 12      2018-09-07 22:20:00                  20             CLEAR
# ...

# %%
#traffic_df['Date'] = traffic_df['CRASH_DATE_ADJ'].dt.date
trafficfinal_df=weatherfinal_df.join(traffic_df.set_index('DATE'), on='DATE')

# %%
trafficfinal_df=trafficfinal_df.dropna()

# %%
trafficfinal_df.to_csv('Traffic_Crashes_-_Crashes.csv', encoding='utf-8', index=False)
