# %%
# !pip install geopandas
# !pip install geojsonio
# Out:
# ...
#     100% |████████████████████████████████| 901kB 2.8MB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 21.6MB 96kB/s eta 0:00:011   13% |████▍                           | 2.9MB 2.7MB/s eta 0:00:07    34% |███████████▏                    | 7.5MB 3.3MB/s eta 0:00:05    38% |████████████▎                   | 8.3MB 3.2MB/s eta 0:00:05    53% |█████████████████▏              | 11.6MB 2.3MB/s eta 0:00:05    57% |██████████████████▍             | 12.4MB 24.9MB/s eta 0:00:01    79% |█████████████████████████▎      | 17.1MB 3.6MB/s eta 0:00:02    81% |██████████████████████████▏     | 17.6MB 812kB/s eta 0:00:05    96% |██████████████████████████████▊ | 20.7MB 1.0MB/s eta 0:00:01
# ...
#     100% |████████████████████████████████| 4.4MB 950kB/s ta 0:00:011
# ...
#     100% |████████████████████████████████| 1.6MB 822kB/s ta 0:00:011
# ...
#   Running setup.py bdist_wheel for pyproj ... done
# ...

# %%
import geopandas as gpd
import geojsonio
import pandas as pd

# %%
# Load up the OSM data
df = gpd.read_file('Boundaries - Police Beats (current).geojson')

# %%
df
# Out:
#     district beat_num sector beat  \
# 0         17     1713      1    1
# 1         31     3100      0    0
# 2         19     1914      1    1
# 3         19     1915      1    1
# 4         19     1913      1    1
# 5         19     1912      1    1
# 6         19     1911      1    1
# 7         17     1723      2    2
# 8         17     1722      2    2
# 9         17     1724      2    2
# 10        16     1624      2    2
# 11        16     1632      3    3
# 12        19     1925      2    2
# 13        19     1923      2    2
# 14        19     1922      2    2
# 15        19     1921      2    2
# 16        17     1733      3    3
# 17        17     1732      3    3
# 18        17     1731      3    3
# 19        16     1634      3    3
# 20        16     1633      3    3
# 21        16     1631      3    3
# 22        19     1924      2    2
# 23        19     1934      3    3
# 24        19     1933      3    3
# 25        24     2422      2    2
# ...

# %%
print(df.geometry)

# %%
pass_df = df.to_json()
geojsonio.display(pass_df)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationFailed                      Traceback (most recent call last)
# <ipython-input-15-3e55879e5bc0> in <module>()
#       1 pass_df = df.to_json()
# ----> 2 geojsonio.display(pass_df)
#
# /anaconda3/lib/python3.6/site-packages/geojsonio/geojsonio.py in display(contents, domain, force_gist)
#      34
#      35     """
# ---> 36     url = make_url(contents, domain, force_gist)
#      37     webbrowser.open(url)
#      38     return url
#
# /anaconda3/lib/python3.6/site-packages/geojsonio/geojsonio.py in make_url(contents, domain, force_gist, size_for_gist)
#      91         url = data_url(contents, domain)
#      92     else:
# ---> 93         gist = _make_gist(contents)
#      94         url = gist_url(gist.id, domain)
#      95
#
# /anaconda3/lib/python3.6/site-packages/geojsonio/geojsonio.py in _make_gist(contents, description, filename)
#     170     ghapi = github3.GitHub()
# ...
